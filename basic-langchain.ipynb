// %%
import { load } from "dotenv";
const env = await load();

const process = {
    env
}

// %%
import { ChatOpenAI } from "@langchain/openai";
import { HumanMessage } from "@langchain/core/messages";

const model = new ChatOpenAI();

const response = await model.invoke([
    new HumanMessage("Tell me a joke")
]);
console.log(response.content);
// Out:
// Why did the scarecrow win an award? Because he was outstanding in his field!

// %%
import { ChatOpenAI } from "@langchain/openai";
import { HumanMessage } from "@langchain/core/messages";
import { StringOutputParser } from "@langchain/core/output_parsers";

const chatModel = new ChatOpenAI();
const outputPrase = new StringOutputParser();

const simpleChain = chatModel.pipe(outputPrase)

await simpleChain.invoke([
    new HumanMessage("Tell me a joke")
])
// Out:
// "Why did the bicycle fall over?\n\nBecause it was two tired!"

// %%
await simpleChain.batch([
    [ new HumanMessage("Tell me a joke") ],
    [ new HumanMessage("Hi, Who are you?") ],
])
// Out:
// [
//   "Why don't scientists trust atoms? \n\nBecause they make up everything!",
//   "Hello! I am an AI assistant designed to help with various tasks and provide information. How can I assist you today?"
// ]

// %%
const stream = await simpleChain.stream([
     new HumanMessage("Tell me a joke")
])

for await (const chunk of stream){
    console.log(chunk)
}
// Out:
// Why
//  don
// 't
//  scientists
//  trust
//  atoms
// ?
//
//
// Because
//  they
//  make
//  up
//  everything
// !

// %%
const stream = await simpleChain.streamLog([
     new HumanMessage("Tell me a joke")
])

for await (const chunk of stream){
    console.log(chunk)
}
// Out:
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "",
//       value: {
//         id: "dc08b21a-b1ba-48aa-bb15-69f482ea9b7a",
//         name: "RunnableSequence",
//         type: "chain",
//         streamed_output: [],
//         final_output: undefined,
//         logs: {}
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI",
//       value: {
//         id: "0b2c4a91-6a79-46e3-8cb6-45444bf54a17",
//         name: "ChatOpenAI",
//         type: "llm",
//         tags: [ "seq:step:1" ],
//         metadata: {},
//         start_time: "2024-08-06T09:46:30.757Z",
//         streamed_output: [],
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser",
//       value: {
//         id: "1c12b05f-616f-4904-a39c-58314ee6eaeb",
//         name: "StrOutputParser",
//         type: "parser",
//         tags: [ "seq:step:2" ],
//         metadata: {},
//         start_time: "2024-08-06T09:46:31.703Z",
//         streamed_output: [],
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: "",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "Why"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Why" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "Why"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "Why",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: "Why",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " don"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " don" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " don"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " don",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " don",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "'t"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "'t" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "'t"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "'t",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: "'t",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " scientists"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " scientists" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " scientists"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " scientists",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " scientists",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " trust"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " trust" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " trust"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " trust",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " trust",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " atoms"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " atoms" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " atoms"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " atoms",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " atoms",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "?"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "?" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "?"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "?",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: "?",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " \n\n"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " \n\n" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " \n\n"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " \n\n",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " \n\n",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "Because"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Because" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "Because"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "Because",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: "Because",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " they"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " they" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " they"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " they",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " they",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " make"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " make" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " make"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " make",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " make",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " up"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " up" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " up"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " up",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " up",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " everything"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " everything" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " everything"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " everything",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: " everything",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "!"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "!" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "!"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "!",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: null },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: "!",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "",
//         generationInfo: { prompt: 0, completion: 0, finish_reason: "stop" },
//         message: AIMessageChunk {
//           lc_serializable: true,
//           lc_kwargs: [Object],
//           lc_namespace: [Array],
//           content: "",
//           name: undefined,
//           additional_kwargs: {},
//           response_metadata: [Object]
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/final_output",
//       value: { generations: [ [Array] ] }
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/end_time",
//       value: "2024-08-06T09:46:31.829Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/final_output",
//       value: {
//         output: "Why don't scientists trust atoms? \n\nBecause they make up everything!"
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/end_time",
//       value: "2024-08-06T09:46:31.830Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "/final_output",
//       value: {
//         output: "Why don't scientists trust atoms? \n\nBecause they make up everything!"
//       }
//     }
//   ]
// }

// %%
import { ChatOpenAI } from "@langchain/openai";

const fakeLLM = new ChatOpenAI({
    azureOpenAIApiKey: "123",
    maxRetries: 0,
});

// await fakeLLM.invoke("你好")

const realLLM = new ChatOpenAI()
const llmWithFallback = fakeLLM.withFallbacks({
    fallbacks: [realLLM]
})

await llmWithFallback.invoke("你好")
// Out:
// Stack trace:
// Error: Azure OpenAI API instance name not found
//     at new ChatOpenAI (file:///Users/dfl/Library/Caches/deno/npm/registry.npmmirror.com/@langchain/openai/0.0.22/dist/chat_models.js:376:23)
//     at <anonymous>:2:17
